# %%
#Defino la clase TiendaOnline
class TiendaOnline:

    #Inicializo los atributos que son inventario, clientes y ventas_totales
    def __init__(self):
        self.inventario = []   #Inicialmente inventario es una lista vacía. Se compone de diccionarios con la siguiente estructura: {'nombre' : nombre, 'precio' : precio, 'cantidad': cantidad}
        self.clientes = {}  #Inicialmente clientes es un diccionario vacío
        self.ventas_totales = 0.0 #Inicialmente ventas_totales toma el valor de cero

    #Ejercicio 1: Definimos el primer método: agregar_producto
    def agregar_producto(self, nombre, precio, cantidad):

        #Declaramos nombre y cantidad como atributos del objeto ya que se usarán en métodos posteriores
        self.nombre = nombre #Se utiliza más adelante en el ejercicio 3 
        self.cantidad = cantidad #Se utiliza más adelante en el ejercicio 4

        #Defino la variable nuevo_producto:
        nuevo_producto = {'nombre' : nombre, 'precio' : precio, 'cantidad': cantidad}

        #Si la lista está vacía:
        if not self.inventario: #self.inventario = False por ser una lista vacía. Añado el not para que la condición sea verdadera. Es equivaente a escribir que  la lista está vacía
            self.inventario.append(nuevo_producto) #Añadimos nuevo_producto al inventario
            return print(f'El primer producto {nuevo_producto} se ha añadido a la lista') #Uso return pero no sé para que si no es con un sentido estético

        #Si la lista no está vacía:  
        elif self.inventario:   
            for producto in self.inventario: #Ahora que tengo un producto al menos en el inventario puedo iterar con un for sobre el mismo. Para cada elemento de la lista inventario al cual llamo producto
                if producto['nombre'] == nombre: #Si el valor para la clave nombre del diccionario es igual al valor que hemos introducido
                    producto['cantidad'] += cantidad
                    return print(f'La cantidad del producto ha sido actualizada. El inventario de tu producto queda como sigue: {producto}')
                
                    #Para que el bucle deje de ejecutarse en cuanto haya encontrado el producto y no siga ejecutándose. O esa función ya la hace return?    
                
            else:
                self.inventario.append(nuevo_producto)
                return print(f'El nuevo producto {nuevo_producto} se ha añadido a la lista')
  
    #Ejercicio 2: creamos el método ver_inventario
    def ver_inventario(self):
        for producto in self.inventario: #Para cada producto dentro del inventario
            print(producto) #Imprimirá el producto. El bucle parará cuando haya imprimido todos los productos del inventario
    #Si inluyo return con el print para el bucle en cuanto ha imprimido el primer producto

    #Ejercicio 3: creamos el método buscar_producto
    def buscar_producto(self, nombre):
        for producto in self.inventario: #Recorre la lista de productos del inventario
            if nombre == producto['nombre']: #Si en dicho producto (o diccionario) el nombre buscado coincide con el valor de 'nombre' para ese producto
                return print('Los detalles del producto que buscas son', producto) #Return para la ejecución del bucle. Es correcto dado que el nombre del producto es único en el inventario              

        else: #En caso de que no encuentre el producto imprimirá la siguiente frase
            print('El producto que buscas no está en el inventario')

    #Ejercicio 4: creamos el método actualizar_stock
    def actualizar_stock(self, nombre, cantidad):

        for producto in self.inventario: #Recorre cada elemento del inventario, es decir, va diccionario a diccionario
            if nombre == producto ['nombre']: #Si encuentra el nombre del producto en el inventario
                producto ['cantidad'] += cantidad  #Suma a la cantidad existente la cantidad de producto que hemos indicado en el método
                return print(f'Stock actualizado: {producto}') #Una vez que lo encuentre paramos el bucle e imprimimos

        else: #Añado esta condición para que nos avise en caso de que el producto no esté creado en el inventario
            print(f'El producto {nombre} no está en el inventario. Añádelo al inventario') 

    #Ejercicio 5: creamos el método eliminar_producto
    def eliminar_producto(self, nombre): 
        
        for producto in self.inventario: #Para cada producto del inventario
            if nombre == producto ['nombre']: #Si el nombre introducido coincide con el nombre de ese producto
                self.inventario.remove(producto) #Elimino el producto del diccionario
                return print(f'El producto {producto} ha sido eliminado del inventario') #Cuando encuentre el nombre parará la ejecución del bucle y devolverá este mensaje

        else: #En el caso de que no encuentre el nombre del producto en el inventario imprimirá el siguiente mensaje
            print(f'No se puede eliminar el producto "{nombre}" pues no está en el inventario')
    
    #Ejercicio 6: creamos el método calcular_valor_inventario

    def calcular_valor_inventario(self):

        suma_acumulada = 0 #Inicializo el valor de la variable suma_acumulada con 0

        for producto in self.inventario: #Para cada producto dentro del inventario
            valor_total_producto = producto['precio'] * producto['cantidad'] #Calcula el valor total que tengo de ese producto
            suma_acumulada += valor_total_producto #En suma_acumulada guardo el valor total del producto actual del bucle más el valor calculado para suma_acumulada en las anteriores iteraciones
        return print(f'El valor total del inventario es {suma_acumulada} €') #Una vez recorrido todo el inventario presento el resultado de las operaciones realizadas en el bucle    
            

# Creo una instancia llamada tienda_madrid   
tienda_madrid = TiendaOnline()

#Agrego varios productos al inventario
print('Ejercicio 1: añado varios productos al inventario')
tienda_madrid.agregar_producto('fular', 20, 10) 
tienda_madrid.agregar_producto('pañuelo', 10, 17) 
tienda_madrid.agregar_producto('reloj', 50, 4) 
tienda_madrid.agregar_producto('reloj', 50, 1) 

print('------------------------------------------------------------') #Para mejor visualización de los resultados

#Imprimo el inventario
print('Ejercicio 2: visualizo el inventario')
tienda_madrid.ver_inventario() 

print('------------------------------------------------------------')

#Busco 3 productos en el inventario
print('Ejercicio 3: busco 3 productos en el inventario') 
tienda_madrid.buscar_producto('fular')
tienda_madrid.buscar_producto('reloj')
tienda_madrid.buscar_producto('pantalón')

print('------------------------------------------------------------')

#Actualizo el stock
print('Ejercicio 4: introduzco 2 productos para que actualice el inventario')
tienda_madrid.actualizar_stock('fular', 13)
tienda_madrid.actualizar_stock('blusa', 12)
tienda_madrid.actualizar_stock('reloj', -2)

print('------------------------------------------------------------')

#Elimino un producto del inventario
print('Ejercicio 5: elimino un producto del inventario e imprimo el inventario para comprobar que es correcto')
tienda_madrid.eliminar_producto('fular')
tienda_madrid.eliminar_producto('rosa')
#Compruebo imprimiendo el inventario
tienda_madrid.ver_inventario()

print('------------------------------------------------------------')

#Calculo el valor del inventario
print('Ejercicio 6: calculo el valor total del inventario')
tienda_madrid.calcular_valor_inventario()
# Out:
# Ejercicio 1: añado varios productos al inventario
# El primer producto {'nombre': 'fular', 'precio': 20, 'cantidad': 10} se ha añadido a la lista
# El nuevo producto {'nombre': 'pañuelo', 'precio': 10, 'cantidad': 17} se ha añadido a la lista
# El nuevo producto {'nombre': 'reloj', 'precio': 50, 'cantidad': 4} se ha añadido a la lista
# La cantidad del producto ha sido actualizada. El inventario de tu producto queda como sigue: {'nombre': 'reloj', 'precio': 50, 'cantidad': 5}
# ------------------------------------------------------------
# Ejercicio 2: visualizo el inventario
# {'nombre': 'fular', 'precio': 20, 'cantidad': 10}
# {'nombre': 'pañuelo', 'precio': 10, 'cantidad': 17}
# {'nombre': 'reloj', 'precio': 50, 'cantidad': 5}
# ------------------------------------------------------------
# Ejercicio 3: busco 3 productos en el inventario
# Los detalles del producto que buscas son {'nombre': 'fular', 'precio': 20, 'cantidad': 10}
# ...

# %% [markdown]
# Por algún motivo al intentar realizar el ejercicio 7 (ver a continuación) sin tocar el ejercicio 6 el ejercicio 6 deja de ejecutarse bien

# %%
#Defino la clase TiendaOnline
class TiendaOnline:

    #Inicializo los atributos que son inventario, clientes y ventas_totales
    def __init__(self):
        self.inventario = []   #Inicialmente inventario es una lista vacía. Se compone de diccionarios con la siguiente estructura: {'nombre' : nombre, 'precio' : precio, 'cantidad': cantidad}
        self.clientes = {}  #Inicialmente clientes es un diccionario vacío
        self.ventas_totales = 0.0 #Inicialmente ventas_totales toma el valor de cero

    #Ejercicio 1: Definimos el primer método: agregar_producto
    def agregar_producto(self, nombre, precio, cantidad):

        #Declaramos nombre y cantidad como atributos del objeto ya que se usarán en métodos posteriores
        self.nombre = nombre #Se utiliza más adelante en el ejercicio 3 
        self.cantidad = cantidad #Se utiliza más adelante en el ejercicio 4

        #Defino la variable nuevo_producto:
        nuevo_producto = {'nombre' : nombre, 'precio' : precio, 'cantidad': cantidad}

        #Si la lista está vacía:
        if not self.inventario: #self.inventario = False por ser una lista vacía. Añado el not para que la condición sea verdadera. Es equivaente a escribir que  la lista está vacía
            self.inventario.append(nuevo_producto) #Añadimos nuevo_producto al inventario
            return print(f'El primer producto {nuevo_producto} se ha añadido a la lista') #Uso return pero no sé para que si no es con un sentido estético

        #Si la lista no está vacía:  
        elif self.inventario:   
            for producto in self.inventario: #Ahora que tengo un producto al menos en el inventario puedo iterar con un for sobre el mismo. Para cada elemento de la lista inventario al cual llamo producto
                if producto['nombre'] == nombre: #Si el valor para la clave nombre del diccionario es igual al valor que hemos introducido
                    producto['cantidad'] += cantidad
                    return print(f'La cantidad del producto ha sido actualizada. El inventario de tu producto queda como sigue: {producto}')
                
                    #Para que el bucle deje de ejecutarse en cuanto haya encontrado el producto y no siga ejecutándose. O esa función ya la hace return?    
                
            else:
                self.inventario.append(nuevo_producto)
                return print(f'El nuevo producto {nuevo_producto} se ha añadido a la lista')
  
    #Ejercicio 2: creamos el método ver_inventario
    def ver_inventario(self):
        for producto in self.inventario: #Para cada producto dentro del inventario
            print(producto) #Imprimirá el producto. El bucle parará cuando haya imprimido todos los productos del inventario
    #Si inluyo return con el print para el bucle en cuanto ha imprimido el primer producto

    #Ejercicio 3: creamos el método buscar_producto
    def buscar_producto(self, nombre):
        for producto in self.inventario: #Recorre la lista de productos del inventario
            if nombre == producto['nombre']: #Si en dicho producto (o diccionario) el nombre buscado coincide con el valor de 'nombre' para ese producto
                return print('Los detalles del producto que buscas son', producto) #Return para la ejecución del bucle. Es correcto dado que el nombre del producto es único en el inventario              

        else: #En caso de que no encuentre el producto imprimirá la siguiente frase
            print('El producto que buscas no está en el inventario')

    #Ejercicio 4: creamos el método actualizar_stock
    def actualizar_stock(self, nombre, cantidad):

        for producto in self.inventario: #Recorre cada elemento del inventario, es decir, va diccionario a diccionario
            if nombre == producto ['nombre']: #Si encuentra el nombre del producto en el inventario
                producto ['cantidad'] += cantidad  #Suma a la cantidad existente la cantidad de producto que hemos indicado en el método
                return print(f'Stock actualizado: {producto}') #Una vez que lo encuentre paramos el bucle e imprimimos

        else: #Añado esta condición para que nos avise en caso de que el producto no esté creado en el inventario
            print(f'El producto {nombre} no está en el inventario. Añádelo al inventario') 

    #Ejercicio 5: creamos el método eliminar_producto
    def eliminar_producto(self, nombre): 
        
        for producto in self.inventario: #Para cada producto del inventario
            if nombre == producto ['nombre']: #Si el nombre introducido coincide con el nombre de ese producto
                self.inventario.remove(producto) #Elimino el producto del diccionario
                return print(f'El producto {producto} ha sido eliminado del inventario') #Cuando encuentre el nombre parará la ejecución del bucle y devolverá este mensaje

        else: #En el caso de que no encuentre el nombre del producto en el inventario imprimirá el siguiente mensaje
            print(f'No se puede eliminar el producto "{nombre}" pues no está en el inventario')
    
    #Ejercicio 6: creamos el método calcular_valor_inventario

    def calcular_valor_inventario(self):

        suma_acumulada = 0 #Inicializo el valor de la variable suma_acumulada con 0

        for producto in self.inventario: #Para cada producto dentro del inventario
            valor_total_producto = producto['precio'] * producto['cantidad'] #Calcula el valor total que tengo de ese producto
            suma_acumulada += valor_total_producto #En suma_acumulada guardo el valor total del producto actual del bucle más el valor calculado para suma_acumulada en las anteriores iteraciones
        return print(f'El valor total del inventario es {suma_acumulada} €') #Una vez recorrido todo el inventario presento el resultado de las operaciones realizadas en el bucle    

     #Ejercicio 7: introducimos el método realizar_compra

    def realizar_compra(self):
        
        self.ver_inventario() #Presentamos el inventario al cliente
        
        producto_deseado = 'inicialización' #Inicializamos la variable producto_deseado
        
        #Creamos una lista vacía donde iremos guardando los productos que elija el cliente
        carrito_de_compra = [] 

        #Este bucle se ejecutará de forma constante hasta que el producto_escogido tome el 
        # valor "compra finalizada"
        while producto_deseado != 'compra finalizada': 
            
            #Preguntamos al cliente qué producto desea y lo almacenamos en la variable producto_deseado
            producto_deseado = input('¿Qué producto desea comprar? Introduzca el nombre del producto. Si no quiere nada más introduzca "compra finalizada"')
            
            #Preguntamos al cliente el número de unidades deseadas del producto y lo almacenamos en la variable unidades_deseadas
            unidades_deseadas = input(f'¿Cuántas unidades de {producto_deseado} desea?')

            #Creamos un diccionario que contenga los productos escogidos por el cliente
            #Primero tenemos que buscar el precio del producto solicitado en el inventario. 
            #Lo almacenamos en precio_producto_deseado
            for producto in self.inventario:
                if producto_deseado == producto['nombre']:
                    precio_producto_deseado = producto['precio']
                    
            producto_en_el_carrito = {'nombre' : producto_deseado, 'precio' : precio_producto_deseado, 'cantidad' : unidades_deseadas}
            
            #Agregamos el producto al carrito de la compra
            carrito_de_compra.append(producto_en_el_carrito) #Añadimos el producto al carrito de la compra
            
            #Actualizamos el stock en almacén
            self.actualizar_stock(producto_deseado, unidades_deseadas) #Actualizamos el inventario

        #Con el carrito completo podemos pasar a calcular el coste de la compra

        suma_productos = 0 #Inicializo la suma de todos los productos a cero

        for producto in carrito_de_compra:
            coste_total_del_producto = producto['precio'] * producto['cantidad']
            suma_productos += coste_total_del_producto       

# Creo una instancia llamada tienda_madrid   
tienda_madrid = TiendaOnline()

#Agrego varios productos al inventario
print('Ejercicio 1: añado varios productos al inventario')
tienda_madrid.agregar_producto('fular', 20, 10) 
tienda_madrid.agregar_producto('pañuelo', 10, 17) 
tienda_madrid.agregar_producto('reloj', 50, 4) 
tienda_madrid.agregar_producto('reloj', 50, 1) 

print('------------------------------------------------------------') #Para mejor visualización de los resultados

#Imprimo el inventario
print('Ejercicio 2: visualizo el inventario')
tienda_madrid.ver_inventario() 

print('------------------------------------------------------------')

#Busco 3 productos en el inventario
print('Ejercicio 3: busco 3 productos en el inventario') 
tienda_madrid.buscar_producto('fular')
tienda_madrid.buscar_producto('reloj')
tienda_madrid.buscar_producto('pantalón')

print('------------------------------------------------------------')

#Actualizo el stock
print('Ejercicio 4: introduzco 2 productos para que actualice el inventario')
tienda_madrid.actualizar_stock('fular', 13)
tienda_madrid.actualizar_stock('blusa', 12)
tienda_madrid.actualizar_stock('reloj', -2)

print('------------------------------------------------------------')

#Elimino un producto del inventario
print('Ejercicio 5: elimino un producto del inventario e imprimo el inventario para comprobar que es correcto')
tienda_madrid.eliminar_producto('fular')
tienda_madrid.eliminar_producto('rosa')
#Compruebo imprimiendo el inventario
tienda_madrid.ver_inventario()

print('------------------------------------------------------------')

#Calculo el valor del inventario
print('Ejercicio 6: calculo el valor total del inventario')
tienda_madrid.calcular_valor_inventario()

print('------------------------------------------------------------')

#Hacemos una compra
print('Ejercicio 7: haciendo una compra')
tienda_madrid.realizar_compra()
# Out:
# Ejercicio 1: añado varios productos al inventario
# El primer producto {'nombre': 'fular', 'precio': 20, 'cantidad': 10} se ha añadido a la lista
# El nuevo producto {'nombre': 'pañuelo', 'precio': 10, 'cantidad': 17} se ha añadido a la lista
# El nuevo producto {'nombre': 'reloj', 'precio': 50, 'cantidad': 4} se ha añadido a la lista
# La cantidad del producto ha sido actualizada. El inventario de tu producto queda como sigue: {'nombre': 'reloj', 'precio': 50, 'cantidad': 5}
# ------------------------------------------------------------
# Ejercicio 2: visualizo el inventario
# {'nombre': 'fular', 'precio': 20, 'cantidad': 10}
# {'nombre': 'pañuelo', 'precio': 10, 'cantidad': 17}
# {'nombre': 'reloj', 'precio': 50, 'cantidad': 5}
# ------------------------------------------------------------
# Ejercicio 3: busco 3 productos en el inventario
# Los detalles del producto que buscas son {'nombre': 'fular', 'precio': 20, 'cantidad': 10}
# ...
